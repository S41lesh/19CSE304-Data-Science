# %%
#1
import pandas as pd
df = pd.read_csv('/content/Absenteeism_at_work.csv',sep = ';',engine = 'python')
df.sample(10)
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 586  28                  23                 2                3        2
# 676  25                  28                 5                4        3
# 110  34                  27                12                6        4
# 243  18                   1                 7                2        1
# 42    3                  23                 9                3        1
# 714   2                   0                 6                2        3
# 74   20                  19                10                5        4
# 235  28                  28                 6                5        1
# 682  26                  19                 5                6        3
# 683  29                  22                 5                6        3
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# 586                     225                               26             9
# ...

# %%
#2
df.drop(['Son', 'Pet'], axis=1, inplace=True)
df.sample(10)
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 485   5                  26                 8                3        1
# 380   6                  22                 2                2        2
# 675  29                  19                 5                4        3
# 531  28                  13                10                3        4
# 47   15                  23                 9                5        1
# 286  15                  28                 9                6        4
# 358  28                  23                 1                4        2
# 284  36                  28                 9                5        4
# 644  22                  23                 3                6        2
# 592  29                  28                 2                6        2
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# 485                     235                               20            13
# ...

# %%
#3
df.isnull().count()  #none of the values is null
# Out:
# ID                                 740
# Reason for absence                 740
# Month of absence                   740
# Day of the week                    740
# Seasons                            740
# Transportation expense             740
# Distance from Residence to Work    740
# Service time                       740
# Age                                740
# Work load Average/day              740
# Hit target                         740
# Disciplinary failure               740
# Education                          740
# Social drinker                     740
# Social smoker                      740
# Weight                             740
# Height                             740
# Body mass index                    740
# Absenteeism time in hours          740
# dtype: int64

# %%
#4
import seaborn as sns
import numpy as np
sns.boxplot(df['Service time'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#4
print(np.where(df['Service time']>25))
# Out:
# (array([234, 507, 510, 513, 576]),)

# %%
#4
sns.boxplot(df['Age'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#4
print(np.where(df['Age']>55))
# Out:
# (array([255, 434, 521, 620, 622, 640, 727, 729]),)

# %%
#5
df['Service time'].corr(df['Age'])
# Out:
# 0.670978916918052

# %%
#6
df.describe()
# Out:
#                ID  Reason for absence  Month of absence  Day of the week  \
# count  740.000000          740.000000        740.000000       740.000000
# mean    18.017568           19.216216          6.324324         3.914865
# std     11.021247            8.433406          3.436287         1.421675
# min      1.000000            0.000000          0.000000         2.000000
# 25%      9.000000           13.000000          3.000000         3.000000
# 50%     18.000000           23.000000          6.000000         4.000000
# 75%     28.000000           26.000000          9.000000         5.000000
# max     36.000000           28.000000         12.000000         6.000000
#
#           Seasons  Transportation expense  Distance from Residence to Work  \
# count  740.000000              740.000000                       740.000000
# mean     2.544595              221.329730                        29.631081
# std      1.111831               66.952223                        14.836788
# ...

# %%
#7
df.head(3)
# Out:
#    ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0  11                  26                 7                3        1
# 1  36                   0                 7                3        1
# 2   3                  23                 7                4        1
#
#    Transportation expense  Distance from Residence to Work  Service time  Age  \
# 0                     289                               36            13   33
# 1                     118                               13            18   50
# 2                     179                               51            18   38
#
#    Work load Average/day   Hit target  Disciplinary failure  Education  \
# 0                 239.554          97                     0          1
# 1                 239.554          97                     1          1
# 2                 239.554          97                     0          1
#
#    Social drinker  Social smoker  Weight  Height  Body mass index  \
# ...

# %%
#8
df.tail(4)
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 736   1                  11                 7                3        1
# 737   4                   0                 0                3        1
# 738   8                   0                 0                4        2
# 739  35                   0                 0                6        3
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# 736                     235                               11            14
# 737                     118                               14            13
# 738                     231                               35            14
# 739                     179                               45            14
#
#      Age  Work load Average/day   Hit target  Disciplinary failure  Education  \
# 736   37                 264.604          93                     0          3
# ...

# %%
#9
df.iloc[(df.index%1000)==253].head(1)
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 253  30                  19                 8                6        1
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# 253                     157                               27             6
#
#      Age  Work load Average/day   Hit target  Disciplinary failure  Education  \
# 253   29                 265.615          94                     0          1
#
#      Social drinker  Social smoker  Weight  Height  Body mass index  \
# 253               1              1      75     185               22
#
#      Absenteeism time in hours
# 253                          3

# %%
#10
df.shape[0] #no of rows
# Out:
# 740

# %%
#11
df.iloc[0:5 , :5]
# Out:
#    ID  Reason for absence  Month of absence  Day of the week  Seasons
# 0  11                  26                 7                3        1
# 1  36                   0                 7                3        1
# 2   3                  23                 7                4        1
# 3   7                   7                 7                5        1
# 4  11                  23                 7                5        1

# %%
#12
df[df["Reason for absence"]==9].count()[0]
# Out:
# 4

# %%
#13
m=df['Body mass index'] >30
gt = df[m]
n= df['Body mass index'] <=30
lt=df[n]
z=lt['Body mass index'] >25
ggt =lt[z]
ggt
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0    11                  26                 7                3        1
# 4    11                  23                 7                5        1
# 6    10                  22                 7                6        1
# 9     1                  22                 7                2        1
# 22   10                  13                 8                2        1
# ..   ..                 ...               ...              ...      ...
# 728  34                  28                 7                2        1
# 731  34                  23                 7                4        1
# 732  10                  22                 7                4        1
# 735  11                  14                 7                3        1
# 736   1                  11                 7                3        1
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# ...

# %%
#13
gt
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 1    36                   0                 7                3        1
# 2     3                  23                 7                4        1
# 5     3                  23                 7                6        1
# 13    3                  11                 7                4        1
# 14    3                  23                 7                4        1
# ..   ..                 ...               ...              ...      ...
# 714   2                   0                 6                2        3
# 716  36                  19                 6                5        3
# 725   5                  26                 7                4        1
# 737   4                   0                 0                3        1
# 738   8                   0                 0                4        2
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# ...

# %%
#14
print("Mean and standard deviation of highscoolers : ",df["Age"][df["Education"]==1].mean(),"and",df["Age"][df["Education"]==1].std())
print("Mean and standard deviation of graduates : ",df["Age"][df["Education"]==2].mean(),"and",df["Age"][df["Education"]==2].std())
print("Mean and standard deviation of postgraduates : ",df["Age"][df["Education"]==3].mean(),"and",df["Age"][df["Education"]==3].std())
# Out:
# Mean and standard deviation of highscoolers :  37.14238952536825 and 6.639006951133699
# Mean and standard deviation of graduates :  34.0 and 5.501514942874069
# Mean and standard deviation of postgraduates :  32.29113924050633 and 3.105627228172035

# %%
#15
print("Mean ",df["Transportation expense"].mean())
print("variance ",df["Transportation expense"].var())
# Out:
# Mean  221.32972972972973
# variance  4482.600197491131

# %%
#16
import matplotlib.pyplot as plt
x = df["Age"][df["Social drinker"]==1]
x
plt.xlabel("age")
plt.hist(x, bins = [0,20,40,60,80,100])
plt.show()
df["Age"].skew() #since the value is positive its an positive skew
# Out:
# 0.6977034092133707
